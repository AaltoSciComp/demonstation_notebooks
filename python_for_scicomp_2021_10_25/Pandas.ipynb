# %%
import pandas as pd

# %%
url = "https://raw.githubusercontent.com/pandas-dev/pandas/master/doc/data/titanic.csv"
titanic = pd.read_csv(url)

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
titanic.groupby("Survived")["Age"].mean()
# Out:
# Survived
# 0    30.626179
# 1    28.343690
# Name: Age, dtype: float64

# %%
titanic.hist(column='Age', by='Survived', bins=25, figsize=(8,10), layout=(2,1), zorder=2, sharex=True, rwidth=0.9);

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
titanic["Age"]
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
titanic.Age
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
titanic = titanic.set_index("Name")

# %%
titanic
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
# ...                                                         ...       ...
# Montvila, Rev. Juozas                                       887         0
# Graham, Miss. Margaret Edith                                888         1
# Johnston, Miss. Catherine Helen "Carrie"                    889         0
# Behr, Mr. Karl Howell                                       890         1
# Dooley, Mr. Patrick                                         891         0
#
# ...

# %%
titanic.at["Heikkinen, Miss. Laina", "Age"]
# Out:
# 26.0

# %%
titanic.loc["Heikkinen, Miss. Laina", "Age"]
# Out:
# 26.0

# %%
titanic.iloc[[3,5,6]]
# Out:
#                                               PassengerId  Survived  Pclass  \
# Name
# Futrelle, Mrs. Jacques Heath (Lily May Peel)            4         1       1
# Moran, Mr. James                                        6         0       3
# McCarthy, Mr. Timothy J                                 7         0       1
#
#                                                  Sex   Age  SibSp  Parch  \
# Name
# Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# Moran, Mr. James                                male   NaN      0      0
# McCarthy, Mr. Timothy J                         male  54.0      0      0
#
#                                               Ticket     Fare Cabin Embarked
# Name
# Futrelle, Mrs. Jacques Heath (Lily May Peel)  113803  53.1000  C123        S
# Moran, Mr. James                              330877   8.4583   NaN        Q
# McCarthy, Mr. Timothy J                        17463  51.8625   E46        S

# %%
titanic.loc[ titanic["Age"] > 70 ]
# Out:
#                                       PassengerId  Survived  Pclass   Sex  \
# Name
# Goldschmidt, Mr. George B                      97         0       1  male
# Connors, Mr. Patrick                          117         0       3  male
# Artagaveytia, Mr. Ramon                       494         0       1  male
# Barkworth, Mr. Algernon Henry Wilson          631         1       1  male
# Svensson, Mr. Johan                           852         0       3  male
#
#                                        Age  SibSp  Parch    Ticket     Fare  \
# Name
# Goldschmidt, Mr. George B             71.0      0      0  PC 17754  34.6542
# Connors, Mr. Patrick                  70.5      0      0    370369   7.7500
# Artagaveytia, Mr. Ramon               71.0      0      0  PC 17609  49.5042
# Barkworth, Mr. Algernon Henry Wilson  80.0      0      0     27042  30.0000
# Svensson, Mr. Johan                   74.0      0      0    347060   7.7750
#
# ...

# %%
titanic["Age"] > 70
# Out:
# Name
# Braund, Mr. Owen Harris                                False
# Cumings, Mrs. John Bradley (Florence Briggs Thayer)    False
# Heikkinen, Miss. Laina                                 False
# Futrelle, Mrs. Jacques Heath (Lily May Peel)           False
# Allen, Mr. William Henry                               False
#                                                        ...
# Montvila, Rev. Juozas                                  False
# Graham, Miss. Margaret Edith                           False
# Johnston, Miss. Catherine Helen "Carrie"               False
# Behr, Mr. Karl Howell                                  False
# Dooley, Mr. Patrick                                    False
# Name: Age, Length: 891, dtype: bool

# %%
df = pd.DataFrame([
        {'Runner': 'Runner 1', 400: 64, 800: 128, 1200: 192, 1500: 240},
        {'Runner': 'Runner 2', 400: 80, 800: 160, 1200: 240, 1500: 300},
        {'Runner': 'Runner 3', 400: 96, 800: 192, 1200: 288, 1500: 360},
         ])

# %%
df
# Out:
#      Runner  400  800  1200  1500
# 0  Runner 1   64  128   192   240
# 1  Runner 2   80  160   240   300
# 2  Runner 3   96  192   288   360

# %%
df = pd.melt(df, id_vars="Runner", value_vars=[400, 800, 1200, 1500], var_name="Distance", value_name="time")

# %%
df
# Out:
#       Runner Distance  time
# 0   Runner 1      400    64
# 1   Runner 2      400    80
# 2   Runner 3      400    96
# 3   Runner 1      800   128
# 4   Runner 2      800   160
# 5   Runner 3      800   192
# 6   Runner 1     1200   192
# 7   Runner 2     1200   240
# 8   Runner 3     1200   288
# 9   Runner 1     1500   240
# 10  Runner 2     1500   300
# 11  Runner 3     1500   360

# %%
df[ df["Distance"] > 800 ]
# Out:
#       Runner Distance  time
# 6   Runner 1     1200   192
# 7   Runner 2     1200   240
# 8   Runner 3     1200   288
# 9   Runner 1     1500   240
# 10  Runner 2     1500   300
# 11  Runner 3     1500   360

# %%
df.groupby('Runner')['time'].plot(x="Distance", y="time")
# Out:
# Runner
# Runner 1    AxesSubplot(0.125,0.125;0.775x0.755)
# Runner 2    AxesSubplot(0.125,0.125;0.775x0.755)
# Runner 3    AxesSubplot(0.125,0.125;0.775x0.755)
# Name: time, dtype: object

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 891 entries, Braund, Mr. Owen Harris to Dooley, Mr. Patrick
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Sex          891 non-null    object
#  4   Age          714 non-null    float64
#  5   SibSp        891 non-null    int64
#  6   Parch        891 non-null    int64
#  7   Ticket       891 non-null    object
#  8   Fare         891 non-null    float64
#  9   Cabin        204 non-null    object
#  10  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 115.8+ KB

# %%
titanic[["Age", "Survived"]]
# Out:
#                                                      Age  Survived
# Name
# Braund, Mr. Owen Harris                             22.0         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  38.0         1
# Heikkinen, Miss. Laina                              26.0         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)        35.0         1
# Allen, Mr. William Henry                            35.0         0
# ...                                                  ...       ...
# Montvila, Rev. Juozas                               27.0         0
# Graham, Miss. Margaret Edith                        19.0         1
# Johnston, Miss. Catherine Helen "Carrie"             NaN         0
# Behr, Mr. Karl Howell                               26.0         1
# Dooley, Mr. Patrick                                 32.0         0
#
# [891 rows x 2 columns]

# %%
titanic.loc["Behr, Mr. Karl Howell", "Age"]
# Out:
# 26.0

# %%
titanic.loc["Behr, Mr. Karl Howell", "Survived":"Age"]
# Out:
# Survived       1
# Pclass         1
# Sex         male
# Age         26.0
# Name: Behr, Mr. Karl Howell, dtype: object

# %%
titanic.iloc[[20,25,30], 2:4]
# Out:
#                                                     Pclass     Sex
# Name
# Fynney, Mr. Joseph J                                     2    male
# Asplund, Mrs. Carl Oscar (Selma Augusta Emilia ...       3  female
# Uruchurtu, Don. Manuel E                                 1    male

# %%
import numpy as np
matrix = np.random.rand(6,4)

# %%
df = pd.DataFrame(
    matrix,
    columns=["A", "B", "C", "D"],
    index=pd.date_range('20211021', periods=6)
)
df
# Out:
#                    A         B         C         D
# 2021-10-21  0.522419  0.049591  0.886332  0.956584
# 2021-10-22  0.559358  0.419414  0.662141  0.870196
# 2021-10-23  0.152975  0.851794  0.591469  0.641172
# 2021-10-24  0.486877  0.372357  0.282450  0.656615
# 2021-10-25  0.970410  0.768879  0.920688  0.240811
# 2021-10-26  0.220578  0.305685  0.387631  0.469634

# %%
ages = pd.DataFrame({
    'Runner': ["Runner 1", "Runner 2", "Runner 3"],
    'Age': [21, 18, 29]
})
ages
# Out:
#      Runner  Age
# 0  Runner 1   21
# 1  Runner 2   18
# 2  Runner 3   29

# %%
sub1, sub2 = df.iloc[:2], df.iloc[2:]

# %%
sub1
# Out:
#      Runner  Age
# 0  Runner 1   21
# 1  Runner 2   18

# %%
sub2
# Out:
#      Runner  Age
# 2  Runner 3   29

# %%
pd.concat([sub1, sub2])
# Out:
#      Runner  Age
# 0  Runner 1   21
# 1  Runner 2   18
# 2  Runner 3   29

# %%
df
# Out:
#       Runner Distance  time
# 0   Runner 1      400    64
# 1   Runner 2      400    80
# 2   Runner 3      400    96
# 3   Runner 1      800   128
# 4   Runner 2      800   160
# 5   Runner 3      800   192
# 6   Runner 1     1200   192
# 7   Runner 2     1200   240
# 8   Runner 3     1200   288
# 9   Runner 1     1500   240
# 10  Runner 2     1500   300
# 11  Runner 3     1500   360

# %%
ages
# Out:
#      Runner  Age
# 0  Runner 1   21
# 1  Runner 2   18
# 2  Runner 3   29

# %%
df.merge(ages, on="Runner")
# Out:
#       Runner Distance  time  Age
# 0   Runner 1      400    64   21
# 1   Runner 1      800   128   21
# 2   Runner 1     1200   192   21
# 3   Runner 1     1500   240   21
# 4   Runner 2      400    80   18
# 5   Runner 2      800   160   18
# 6   Runner 2     1200   240   18
# 7   Runner 2     1500   300   18
# 8   Runner 3      400    96   29
# 9   Runner 3      800   192   29
# 10  Runner 3     1200   288   29
# 11  Runner 3     1500   360   29

# %%
titanic.groupby("Sex")["Survived"].mean()
# Out:
# Sex
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64

# %%
titanic["Child"] = titanic["Age"] < 12
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 891 entries, Braund, Mr. Owen Harris to Dooley, Mr. Patrick
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Sex          891 non-null    object
#  4   Age          714 non-null    float64
#  5   SibSp        891 non-null    int64
#  6   Parch        891 non-null    int64
#  7   Ticket       891 non-null    object
#  8   Fare         891 non-null    float64
#  9   Cabin        204 non-null    object
#  10  Embarked     889 non-null    object
#  11  Child        891 non-null    bool
# dtypes: bool(1), float64(2), int64(5), object(4)
# memory usage: 116.7+ KB

# %%
titanic.groupby(["Sex", "Child"])["Survived"].mean()
# Out:
# Sex     Child
# female  False    0.758865
#         True     0.593750
# male    False    0.164510
#         True     0.555556
# Name: Survived, dtype: float64

# %%
titanic.boxplot(column="Age", by=["Child", "Sex"])
# Out:
# <AxesSubplot:title={'center':'Age'}, xlabel='[Child, Sex]'>

# %%
titanic.groupby("Pclass")["Fare"].mean().plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='Pclass'>

# %%
titanic.boxplot(column="Age", by=["Child","Sex"])
# Out:
# <AxesSubplot:title={'center':'Age'}, xlabel='[Child, Sex]'>

# %%
titanic.groupby("Pclass").mean().plot(kind="bar", y="Fare")
# Out:
# <AxesSubplot:xlabel='Pclass'>
